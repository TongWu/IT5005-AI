# %% [markdown]
# # IT5005 Artificial Intelligence Term Assignment
#
# Fill your name and student number below:
#
#
# | Student Number: | Name:                   |
# |:----------------|:------------------------|
# | A0255954R       | Wu Tong              |
# | A0286177N       | Yang Haohong              |
#
#
#
# ## 1. Introduction
#
# In this assignment we hope to achieve the following:
#
#     1. An understanding of the practical limitations of using dense networks in complex tasks
#     2. Hands-on experience in building a deep learning neural network to solve a relatively complex task.
#
# As this lab is more challenging than the tutorial, you can choose to work in teams of 2.
#
# Each step may take a long time to run. You and your partner may want to work out how to do things simultaneously, but please do not miss out on any learning opportunities.
#
#
# ## 2. Submission Instructions
#
#
# ### 2.1 SUBMISSION INSTRUCTIONS
#
# #### If you are working with a partner only ONE submission is required. However please ensure that both names are shown above. Otherwise one person will not get any marks.
#
# Please rename this Jupyter notebook to your student ID (e.g. A1234567Y.ipynb), complete it and submit to Canvas by 12 pm, Sunday 21 April 2024.
#
# The folder will close shortly after 12 pm on 21 April, after which you will no longer be able to submit your assignment and you will get 0.
#
#
# ## 3. Creating a Dense Network for CIFAR-10
#
# We will now begin building a neural network for the CIFAR-10 dataset. The CIFAR-10 dataset consists of 50,000 32x32x3 (32x32 pixels, RGB channels) training images and 10,000 testing images (also 32x32x3), divided into the following 10 categories:
#
#     1. Airplane
#     2. Automobile
#     3. Bird
#     4. Cat
#     5. Deer
#     6. Dog
#     7. Frog
#     8. Horse
#     9. Ship
#     10. Truck
#
# In the first two parts of this lab we will create a classifier for the CIFAR-10 dataset.
#
# ### 3.1 Loading the Dataset
#
# We begin firstly by creating a Dense neural network for CIFAR-10. The code below shows how we load the CIFAR-10 dataset:

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import cifar10

def load_cifar10():
    (train_x, train_y), (test_x, test_y) = cifar10.load_data()
    train_x = train_x.reshape(train_x.shape[0], 3072) # Question 1
    test_x = test_x.reshape(test_x.shape[0], 3072) # Question 1
    train_x = train_x.astype('float32')
    test_x = test_x.astype('float32')
    train_x /= 255.0
    test_x /= 255.0
    ret_train_y = to_categorical(train_y,10)
    ret_test_y = to_categorical(test_y, 10)
    
    return (train_x, ret_train_y), (test_x, ret_test_y)


(train_x, train_y), (test_x, test_y) = load_cifar10()

# %% [markdown]
# ----
#
# #### Question 1
#
# Explain what the following two  statements do, and where the number "3072" came from (2 MARKS):
#
# ```
#   train_x = train_x.reshape(train_x.shape[0], 3072) # Question 1
#   test_x = test_x.reshape(test_x.shape[0], 3072) # Question 1
# ```
#
# ***In CIFAR-10 dataset, the image data is stored as 3D array, which size is 32\*3\*3 (pixels). The method `reshape` convert 3D array to 1D array, each image has been flatten into an 1D array which have length 32\*32\*3 = 3072. The MLP need to input an one-dimensional array to its dense layer due to its structure and internal mechanism.***
#
# *FOR GRADER: _______ / 2*
#
# ### 3.2 Building the MLP Classifier
#
# In the code box below, create a new fully connected (dense) multilayer perceptron classifier for the CIFAR-10 dataset. To begin with, create a network with one hidden layer of 1024 neurons, using the SGD optimizer. You should output the training and validation accuracy at every epoch, and train for 50 epochs:

# %%
""" 
Write your code to build an MLP with one hidden layer of 1024 neurons,
with an SGD optimizer. Train for 100 epochs, and output the training and
validation accuracy at each epoch.
"""
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import SGD

model = Sequential()
model.add(
# Epoch 35/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6680 - loss: 0.9667 - val_accuracy: 0.5170 - val_loss: 1.4183
# Epoch 36/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6714 - loss: 0.9553 - val_accuracy: 0.5313 - val_loss: 1.3603
# Epoch 37/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6757 - loss: 0.9407 - val_accuracy: 0.5365 - val_loss: 1.3321
# Epoch 38/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6794 - loss: 0.9297 - val_accuracy: 0.5234 - val_loss: 1.3806
# Epoch 39/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6818 - loss: 0.9169 - val_accuracy: 0.5060 - val_loss: 1.4625
# Epoch 40/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6872 - loss: 0.9036 - val_accuracy: 0.5167 - val_loss: 1.4301
# Epoch 41/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6953 - loss: 0.8925 - val_accuracy: 0.5227 - val_loss: 1.3950
# Epoch 42/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6956 - loss: 0.8847 - val_accuracy: 0.5294 - val_loss: 1.3993
# Epoch 43/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7007 - loss: 0.8628 - val_accuracy: 0.5158 - val_loss: 1.4450
# Epoch 44/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7034 - loss: 0.8584 - val_accuracy: 0.5334 - val_loss: 1.3784
# Epoch 45/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7118 - loss: 0.8454 - val_accuracy: 0.5342 - val_loss: 1.3694
# Epoch 46/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7189 - loss: 0.8226 - val_accuracy: 0.5442 - val_loss: 1.3444
# Epoch 47/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7222 - loss: 0.8210 - val_accuracy: 0.5453 - val_loss: 1.3583
# Epoch 48/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7265 - loss: 0.8054 - val_accuracy: 0.5292 - val_loss: 1.4106
# Epoch 49/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7251 - loss: 0.8040 - val_accuracy: 0.5480 - val_loss: 1.3408
# Epoch 50/50
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7319 - loss: 0.7862 - val_accuracy: 0.5174 - val_loss: 1.4628

# %% [markdown]
# #### Question 2
#
# Complete the following table on the design choices for your MLP
# (3 MARKS):
#
# | Hyperparameter       | What I used | Why?                                                              |
# |:---------------------|:------------|:------------------------------------------------------------------|
# | Optimizer            | SGD         | Specified in question                                             |
# | # of hidden layers   | 1           | Specified in question                                             |
# | # of hidden neurons  | 1024        | Specified in question                                             |
# | Hid layer activation | ReLU        | Solve VGP efficiently                                             |
# | # of output neurons  | 10          | CIFAR-10 has 10 categories, so output layer need 10 neurons       |
# | Output activation    | Softmax     | Softmax can predict each category's possibility in classification |
# | learning_rate        | Default(0.01) | Default value is a good starting point                            |
# | momentum             | Default(0)  | Default is good                                                   |
# | decay                | Default(none) | Default is good                                                   |
# | loss                 | Categorical Crossentropy            | Classification problem usually use CC to optimise performance     |
#
# *For TA: ___ / 3* <br>
# *Code:  ____/ 5* <br>
# **TOTAL: ____ / 8** <br>
#
# #### Question 3:
#
# What was your final training accuracy? Validation accuracy? Is there overfitting / underfitting? Explain your answer (5 MARKS)
#
# ***The final training accuracy is 73.19%, and the validation accuracy is 51.74%. The model may experimenting the overfitting, since there is a large gap between the training and validation accuracy.***
#
# *FOR GRADER: ______ / 5*
#
# ### 3.3 Experimenting with the MLP
#
# Cut and paste your code from Section 3.2 to the box below (you may need to rename your MLP). Experiment with the number of hidden layers, the number of neurons in each hidden layer, the optimization algorithm, etc. See [Keras Optimizers](https://keras.io/optimizers) for the types of optimizers and their parameters. **Train for 100 epochs.**

# %%
"""
Cut and paste your code from Section 3.2 below, then modify it to get
much better results than what you had earlier. E.g. increase the number of
nodes in the hidden layer, increase the number of hidden layers,
change the optimizer, etc. 

Train for 100 epochs.

"""
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam, RMSprop, AdamW
from tensorflow.keras.callbacks import EarlyStopping

model_BetterMLP = Sequential()
model_BetterMLP.add(Input(shape=(3072,)))

model_BetterMLP.add(Dense(2048, activation='relu'))
#model_BetterMLP.add(BatchNormalization())
model_BetterMLP.add(Dropout(0.5))

model_BetterMLP.add(Dense(1024, activation='relu'))
#model_BetterMLP.add(BatchNormalization())
model_BetterMLP.add(Dropout(0.5))

model_BetterMLP.add(Dense(10, activation='softmax'))

model_BetterMLP.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
#early_stopping = EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)

history = model_BetterMLP.fit(train_x, train_y, epochs=100, validation_data=(test_x, test_y), verbose=1)
# Out:
# Epoch 1/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.2225 - loss: 2.1384 - val_accuracy: 0.3554 - val_loss: 1.8105
# Epoch 2/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.3272 - loss: 1.8554 - val_accuracy: 0.3938 - val_loss: 1.7242
# Epoch 3/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.3509 - loss: 1.7940 - val_accuracy: 0.4127 - val_loss: 1.6589
# Epoch 4/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.3744 - loss: 1.7422 - val_accuracy: 0.4348 - val_loss: 1.6101
# Epoch 5/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.3931 - loss: 1.6968 - val_accuracy: 0.4482 - val_loss: 1.5826
# Epoch 6/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.4037 - loss: 1.6705 - val_accuracy: 0.4485 - val_loss: 1.5691
# Epoch 7/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.4162 - loss: 1.6371 - val_accuracy: 0.4567 - val_loss: 1.5369
# Epoch 8/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.4237 - loss: 1.6188 - val_accuracy: 0.4719 - val_loss: 1.5229
# Epoch 9/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.4299 - loss: 1.5984 - val_accuracy: 0.4706 - val_loss: 1.4993
# Epoch 10/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.4347 - loss: 1.5788 - val_accuracy: 0.4727 - val_loss: 1.4903
# Epoch 11/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.4441 - loss: 1.5644 - val_accuracy: 0.4819 - val_loss: 1.4739
# Epoch 12/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.4485 - loss: 1.5416 - val_accuracy: 0.4745 - val_loss: 1.5068
# Epoch 13/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.4571 - loss: 1.5213 - val_accuracy: 0.4967 - val_loss: 1.4484
# Epoch 14/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.4645 - loss: 1.5019 - val_accuracy: 0.4908 - val_loss: 1.4628
# Epoch 15/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.4640 - loss: 1.4985 - val_accuracy: 0.5017 - val_loss: 1.4386
# Epoch 16/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.4700 - loss: 1.4796 - val_accuracy: 0.5051 - val_loss: 1.4192
# Epoch 17/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.4785 - loss: 1.4577 - val_accuracy: 0.5112 - val_loss: 1.4147
# Epoch 18/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.4757 - loss: 1.4622 - val_accuracy: 0.5079 - val_loss: 1.4146
# Epoch 19/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.4826 - loss: 1.4492 - val_accuracy: 0.4966 - val_loss: 1.4201
# Epoch 20/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.4823 - loss: 1.4387 - val_accuracy: 0.5097 - val_loss: 1.3886
# Epoch 21/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.4911 - loss: 1.4250 - val_accuracy: 0.5160 - val_loss: 1.3927
# Epoch 22/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.4928 - loss: 1.4226 - val_accuracy: 0.5142 - val_loss: 1.3905
# Epoch 23/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.4905 - loss: 1.4139 - val_accuracy: 0.5202 - val_loss: 1.3872
# Epoch 24/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.4930 - loss: 1.4126 - val_accuracy: 0.5165 - val_loss: 1.3934
# Epoch 25/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.4999 - loss: 1.4032 - val_accuracy: 0.5212 - val_loss: 1.3588
# Epoch 26/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.4978 - loss: 1.3974 - val_accuracy: 0.5227 - val_loss: 1.3605
# Epoch 27/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.
100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.6140 - loss: 1.0807 - val_accuracy: 0.5578 - val_loss: 1.2719
# Epoch 91/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.6119 - loss: 1.0815 - val_accuracy: 0.5547 - val_loss: 1.2819
# Epoch 92/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.6112 - loss: 1.0829 - val_accuracy: 0.5537 - val_loss: 1.3123
# Epoch 93/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.6094 - loss: 1.0896 - val_accuracy: 0.5619 - val_loss: 1.2808
# Epoch 94/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.6127 - loss: 1.0749 - val_accuracy: 0.5576 - val_loss: 1.2913
# Epoch 95/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.6166 - loss: 1.0761 - val_accuracy: 0.5600 - val_loss: 1.2884
# Epoch 96/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.6172 - loss: 1.0708 - val_accuracy: 0.5648 - val_loss: 1.2816
# Epoch 97/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.6173 - loss: 1.0645 - val_accuracy: 0.5627 - val_loss: 1.2754
# Epoch 98/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.6126 - loss: 1.0730 - val_accuracy: 0.5549 - val_loss: 1.2880
# Epoch 99/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.6211 - loss: 1.0638 - val_accuracy: 0.5570 - val_loss: 1.2827
# Epoch 100/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.6219 - loss: 1.0542 - val_accuracy: 0.5615 - val_loss: 1.2790

# %% [markdown]
# ----
#
# #### Question 4:
#
# Complete the following table with your final design (you may add more rows for the # neurons (layer1) etc. to detail how many neurons you have in each hidden layer). Likewise you may replace the learning_rate, momentum etc rows with parameters more appropriate to the optimizer that you have chosen. (3 MARKS)
#
#
# | Hyperparameter       | What I used | Why?                                                              |
# |:---------------------|:------------|:------------------------------------------------------------------|
# | Optimizer            | Adam        | Converge faster than SGD                                          |
# | # of hidden layers   | 2           | Increase the learning ability of the model, avoid over-fitting    |
# | # neurons(layer1)    | 2048        | Try to catch complexity features                                  |
# | Hid layer1 activation| ReLU        | Solve VGP efficiently                                             |
# | Dropout (layer1)     | 0.5         | Dropout random part of data, avoid over-fitting                   |
# | # neurons(layer2)    | 1024        | Halve the neuron to shrink the feature space                      |
# | Hid layer2 activation| ReLU        | Solve VGP efficiently                                             |
# | Dropout (layer2)     | 0.5         | Dropout random part of data, avoid over-fitting                   |
# | # of output neurons  | 10          | CIFAR-10 has 10 categories, so output layer need 10 neurons       |
# | Output activation    | Softmax     | Softmax can predict each category's possibility in classification |
# | learning_rate        | 0.0001      | Low learning rate help model learn with robustness                |
# | momentum             | None        | Momentum is auto adjusted in Adam                                 |
# | decay                | None        | Decay is achived by Adam's internal mechanism                     |
# | loss                 | Categorical Crossentropy | Classification problem usually use CC to optimise performance     |
#
# *FOR GRADER: _____ / 3 * <br>
# *CODE: ______ / 5 *<br>
#
# ***TOTAL: ______ / 8***
#
# #### Question 5
#
# What is the final training and validation accuracy that you obtained after 100 epochs? Is there considerable improvement over Section 3.2? Are there still signs of underfitting or overfitting? Explain your answer (5 MARKS)
#
# ***The final training accuracy is 62.19%, and the validation accuracy is 56.15%. Overall, the training accuracy is decreased, which may caused by the dropout layer, it avoid the over-fitting problem. The validation accuracy is increased, which means the model improves the generalization of un-seen data. The current model significantly improve the situation of the over-fitting problem.***
#
# *FOR GRADER: ______ / 5 *
#
# #### Question 6
#
# Write a short reflection on the practical difficulties of using a dense MLP to classsify images in the CIFAR-10 datasets. (3 MARKS)
#
# ***When using MLP to classify the CIFAR-10 dataset, we first need to flatten the image data (32\*32\*3) into one-dimensional array, which is 3072-dimensions matrix for input layer. The high-dimensional input increase the computing resources and complexity. Also, dense layers tend to cause the optimization space of the loss function to become very complex when dealing with such high dimensional inputs. Besides, due to the MLP structure, it is more likely to cause over-fitting problem when there is no normalization method applied into model (like dropout layer). Finally, compared with CNN, MLP cannot capture the local correlations and spatial hierarchical structures in images since MLP is handling the one-dimensional data. The spatial relationship is important for image recognition, which limit the accuracy of MLP.***
#
# *FOR GRADER: _______ /3*
#
# ----
#
# ## 4. Creating a CNN for the MNIST Data Set
#
# In this section we will now create a convolutional neural network (CNN) to classify images in the MNIST dataset that we used in the previous lab. Let's go through each part to see how to do this.
#
# ### 4.1 Loading the MNIST Dataset
#
# As always we will load the MNIST dataset, scale the inputs to between 0 and 1, and convert the Y labels to one-hot vectors. However unlike before we will not flatten the 28x28 image to a 784 element vector, since CNNs can inherently handle 2D data.

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

def load_mnist():
    (train_x, train_y),(test_x, test_y) = mnist.load_data()
    train_x = train_x.reshape(train_x.shape[0], 28, 28, 1)
    test_x = test_x.reshape(test_x.shape[0], 28, 28, 1)

    train_x=train_x.astype('float32')
    test_x = test_x.astype('float32')
    
    train_x /= 255.0
    test_x /= 255.0
        
    train_y = to_categorical(train_y, 10)
    test_y = to_categorical(test_y, 10)
        
    return (train_x, train_y), (test_x, test_y)

# %% [markdown]
# ### 4.2 Building the CNN
#
# We will now build the CNN. Unlike before we will create a function to produce the CNN. We will also look at how to save and load Keras models using "checkpoints", particularly "ModelCheckpoint" that saves the model each epoch.
#
# Let's begin by creating the model. We call os.path.exists to see if a model file exists, and call "load_model" if it does. Otherwise we create a new model.

# %%
# load_model loads a model from a hd5 file.
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
import os

MODEL_NAME = 'mnist-cnn.keras'

def buildmodel(model_name):
    if os.path.exists(model_name):
        model = load_model(model_name)                                                                                             
    else:
        model = Sequential()
        model.add(Conv2D(32, kernel_size=(5,5),
        activation='relu',
        input_shape=(28, 28, 1), padding='same')) # Question 7

        model.add(MaxPooling2D(pool_size=(2,2), strides=2)) # Question 8
        model.add(Conv2D(64, kernel_size=(5,5), activation='relu'))
        model.add(Conv2D(128, kernel_size=(5,5), activation='relu'))
        model.add(Conv2D(64, kernel_size=(5,5), activation='relu'))
        model.add(MaxPooling2D(pool_size=(2,2), strides=2))
        model.add(Flatten()) # Question 9
        model.add(Dense(1024, activation='relu'))
        model.add(Dropout(0.1))
        model.add(Dense(10, activation='softmax'))

    return model

# %% [markdown]
# ----
#
# #### Question 7
#
# The first layer in our CNN is a 2D convolution kernel, shown here:
#
# ```
#         model.add(Conv2D(32, kernel_size=(5,5),
#         activation='relu',
#         input_shape=(28, 28, 1), padding='same')) # Question 7
# ```
#
# Why is the input_shape set to (28, 28, 1)? What does this mean? What does "padding = 'same'" mean? (4 MARKS)
#
# ***The MNIST have image size 28\*28 pixels for each image and is grey scale. The (28, 28, 1) means that, each image size is 28\*28 pixels, `1` is denoted as 'grey scale'. "padding = 'same'" means that in a convolutional operation, the boundaries of the image are automatically padded so the output size and input size are the same.***
#
# *FOR GRADER: ______ / 4*
#
# #### Question 8
#
# The second layer is the MaxPooling2D layer shown below:
#
# ```
#         model.add(MaxPooling2D(pool_size=(2,2), strides=2)) # Question 8
# ```
#
# What other types of pooling layers are available? What does 'strides = 2' mean? (3 MARKS)
#
# ***Other types of pooling layers are: AveragePooling2D, GlobalMaxPooling2D, GlobalAveragePooling2D. 'strides = 2' means the pixel number that pooling layer's each time shift. In this case, 2 pixels are shifted at a time, which means that the pooling operation will reduce the spatial size of the input feature map.***
#
# *FOR GRADER: _____ / 3*
#
#
# #### Question 9
#
# What does the "Flatten" layer here do? Why is it needed?
#
# ```
#         model.add(Flatten()) # Question 9
# ```
#
# ***Flatten layer aims to one-dimensionalize the multidimensional input. The previous convolutional and pooling layer will produce high-dimensional feature maps, while the full-connected layer need one-dimensional array.***
#
# *FOR GRADER: ____ / 2*
#
#
#
#
# ----
#
# ### 4.3 Training the CNN
#
# Let's now train the CNN. In this example we introduce the idea of a "callback", which is a routine that Keras calls at the end of each epoch. Specifically we look at two callbacks:
#
#     1. ModelCheckpoint: When called, Keras saves the model to the specified filename.
#
#     2. EarlyStopping: When called, Keras checks if it should stop the training prematurely.
#
#
# Let's look at the code to see how training is done, and how callbacks are used.

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

def train(model, train_x, train_y, epochs, test_x, test_y, model_name):

    model.compile(optimizer=SGD(learning_rate=0.01, momentum=0.7), 
                  loss='categorical_crossentropy', metrics=['accuracy'])

    savemodel = ModelCheckpoint(model_name)
    stopmodel = EarlyStopping(min_delta=0.001, patience=10) # Question 10

    print("Starting training.")

    model.fit(x=train_x, y=train_y, batch_size=32,
    validation_data=(test_x, test_y), shuffle=True,
    epochs=epochs, 
    callbacks=[savemodel, stopmodel])

    print("Done. Now evaluating.")
    loss, acc = model.evaluate(x=test_x, y=test_y)
    print("Test accuracy: %3.2f, loss: %3.2f"%(acc, loss))

# %% [markdown]
# Notice that there isn't very much that is unusual going on; we compile the model with our loss function and optimizer, then call fit, and finally evaluate to look at the final accuracy for the test set.  The only thing unusual is the "callbacks" parameter here in the fit function call
#
# ```
#     model.fit(x=train_x, y=train_y, batch_size=32,
#     validation_data=(test_x, test_y), shuffle=True,
#     epochs=epochs,
#     callbacks=[savemodel, stopmodel])
# ```
#
# ----
#
# #### Question 10.
#
# What does do the min_delta and patience parameters do in the EarlyStopping callback, as shown below? (2 MARKS)
#
# ```
#     stopmodel = EarlyStopping(min_delta=0.001, patience=10) # Question 10
# ```
#
# ***`min_delta` defines the minimum amount of change that is considered as improvement. In this case, the model's monitoring metrics must improve by at least 0,001 to be considered substantially improved, which avoid model continue training caused by tiny and meaningless changes. `patience` defines how many periods of no monitored improvement can be tolerated before traning is stopped. In this case, if no loss improvement of at least 0.001 is observed for 10 consecutive training periods, then training will be stopped early, which in order to avoid over-fitting.***
#
# *FOR GRADER: ____ / 2*
#
# ---
#
# ### 4.4 Putting it together.
#
# Now let's run the code and see how it goes (Note: To save time we are training for only 5 epochs; we should train much longer to get much better results):

# %%
    (train_x, train_y),(test_x, test_y) = load_mnist()
    model = buildmodel(MODEL_NAME)
    train(model, train_x, train_y, 5, test_x, test_y, MODEL_NAME)
# Out:
# Starting training.
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.7399 - loss: 0.8017 - val_accuracy: 0.9765 - val_loss: 0.0735
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9763 - loss: 0.0761 - val_accuracy: 0.9826 - val_loss: 0.0559
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9854 - loss: 0.0470 - val_accuracy: 0.9888 - val_loss: 0.0357
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9889 - loss: 0.0354 - val_accuracy: 0.9902 - val_loss: 0.0335
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9924 - loss: 0.0265 - val_accuracy: 0.9902 - val_loss: 0.0343
# Done. Now evaluating.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9870 - loss: 0.0451
# Test accuracy: 0.99, loss: 0.03

# %% [markdown]
# ----
#
# #### Question 11.
#
# Compare the relative advantages and disadvantages of CNN vs. the Dense MLP that you build in sections 3.2 and 3.3. What makes CNNs better (or worse)? (3 MARKS)
#
# ***1. CNN are able to capture spatial and local correlations of input data through their convolutional layers. 2. CNN reduces the number of model parameters throuh weight sharing, reducing the risk of over-fitting. 3. Converlutional operation is more complex than matrix multiplication, which let CNN need more time to train the same dataset.***
#
# *FOR TA: ______ / 3*
#
# ## 5. Making a CNN for the CIFAR-10 Dataset
#
# Now comes the fun part: Using the example above for creating a CNN for the MNIST dataset, now create a CNN in the box below for the MNIST-10 dataset. At the end of each epoch save the model to a file called "cifar.hd5" (note: the .hd5 is added automatically for you).
#
# ---
#
# #### Question 12.
#
# Summarize your design in the table below (the actual coding cell comes after this):
#
# | Hyperparameter       | What I used | Why?                  |
# |:---------------------|:------------|:----------------------|
# | Optimizer            | Adam            | Faster converging than SGD                      |
# | Input shape          | (32,32,3)            | Default size of CIFAR-10 image                      |
# | First layer group | 2\*Convolutional(Conv2D-32, 3\*3, ReLU), 1\*BatchNormalization, 1\*Maxpooling2D, 1\*Dropout(0.4) | Use two convolutional layers with 32 neurons to capture the basic feature of the image, ReLU can solve VGP. BatchNormalization layer can boost training process, increase the robustness of the model. Dropout layer avoid over-fitting problem. |
# | Second layer group | 2\*Convolutional(Conv2D-64, 3\*3, ReLU), 1\*BatchNormalization, 1\*Maxpooling2D, 1\*Dropout(0.4) | Use two convolutional layers with 64 neurons to capture the deeper feature of the image.                      |
# | Third layer group |  2\*Convolutional(Conv2D-128, 3\*3, ReLU), 1\*BatchNormalization, 1\*Maxpooling2D, 1\*Dropout(0.4) | Use two convolutional layers with 128 neurons try to capture as deeper feature of the image as the model can.                      |
# | Dense layer           | Dense-128, ReLU, Dropout(0.4)            | Synthesize the features extracted from the previous convolutional layers, use 128 neurons to further process the feature.                     |
# | Output layer          | Dense-10, softmax            | CIFAR-10 has 10 categories, so output layer need 10 neuronsCIFAR-10 has 10 categories, so output layer need 10 neurons                      |
#
#
# *FOR TA:*
# *Table: ________ / 3* <br>
# *Code: _________/ 7* <br>
# **TOTAL: _______ / 10** <br>
#
# ---
#
# ***TOTAL: _______ / 55***

# %%
"""
Write your code for your CNN for the CIFAR-10 dataset here. 

Note: train_x, train_y, test_x, test_y were changed when we called 
load_mnist in the previous section. You will now need to call load_cifar10
again.

"""
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Conv2D, MaxPooling2D, BatchNormalization, Dropout, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam, RMSprop, AdamW
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# For CNN, the image should not be flatten, so I create a new load_cifar10_cnn function and call it
def load_cifar10_cnn():
    (train_x, train_y), (test_x, test_y) = cifar10.load_data()
    train_x = train_x.astype('float32') / 255.0
    test_x = test_x.astype('float32') / 255.0
    train_y = to_categorical(train_y, 10)
    test_y = to_categorical(test_y, 10)
    
    return (train_x, train_y), (test_x, test_y)

(train_x, train_y), (test_x, test_y) = load_cifar10_cnn()
# (train_x, train_y), (test_x, test_y) = load_cifar10()

def build_cnn():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.4))

    model.add(Conv2D(64, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.4))

    model.add(Conv2D(128, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.4))
    
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.4))
    model.add(Dense(10, activation='softmax'))

    return model

model_cnn = build_cnn()
model_cnn.compile(
    optimizer=Adam(), 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# ValueError: The filepath provided must end in `.keras` (Keras model format). Received: filepath=cifar.hd5
savemodel_callback = ModelCheckpoint('cifar.keras', save_best_only=True)
stopmodel_callback = EarlyStopping(monitor='val_loss', patience=10, min_delta=0.001)
data_generator = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
train_generator = data_generator.flow(train_x, train_y, 32)

model_cnn.fit(
    x=train_x, 
    y=train_y, 
    batch_size=32, 
    shuffle=True,
    epochs=100, 
    validation_data=(test_x, test_y), 
    callbacks=[savemodel_callback, stopmodel_callback]
)
# Out:
# Epoch 1/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 45s 28ms/step - accuracy: 0.3352 - loss: 1.9941 - val_accuracy: 0.5511 - val_loss: 1.2761
# Epoch 2/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 43s 28ms/step - accuracy: 0.5628 - loss: 1.2365 - val_accuracy: 0.6776 - val_loss: 0.9414
# Epoch 3/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.6466 - loss: 1.0168 - val_accuracy: 0.7215 - val_loss: 0.8050
# Epoch 4/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 43s 28ms/step - accuracy: 0.6874 - loss: 0.9079 - val_accuracy: 0.7261 - val_loss: 0.7754
# Epoch 5/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 43s 27ms/step - accuracy: 0.7125 - loss: 0.8246 - val_accuracy: 0.7631 - val_loss: 0.7049
# Epoch 6/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 42s 27ms/step - accuracy: 0.7414 - loss: 0.7612 - val_accuracy: 0.7611 - val_loss: 0.6990
# Epoch 7/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 44s 28ms/step - accuracy: 0.7600 - loss: 0.7077 - val_accuracy: 0.7941 - val_loss: 0.6036
# Epoch 8/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 44s 28ms/step - accuracy: 0.7706 - loss: 0.6607 - val_accuracy: 0.8015 - val_loss: 0.5946
# Epoch 9/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 43s 28ms/step - accuracy: 0.7870 - loss: 0.6211 - val_accuracy: 0.7996 - val_loss: 0.5993
# Epoch 10/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 43s 28ms/step - accuracy: 0.7986 - loss: 0.5912 - val_accuracy: 0.7945 - val_loss: 0.6346
# Epoch 11/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 47s 30ms/step - accuracy: 0.8025 - loss: 0.5670 - val_accuracy: 0.8161 - val_loss: 0.5569
# Epoch 12/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 42s 27ms/step - accuracy: 0.8193 - loss: 0.5324 - val_accuracy: 0.8179 - val_loss: 0.5387
# Epoch 13/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.8239 - loss: 0.5094 - val_accuracy: 0.8256 - val_loss: 0.5266
# Epoch 14/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 42s 27ms/step - accuracy: 0.8299 - loss: 0.4908 - val_accuracy: 0.7976 - val_loss: 0.6098
# Epoch 15/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 43s 28ms/step - accuracy: 0.8376 - loss: 0.4744 - val_accuracy: 0.8381 - val_loss: 0.4877
# Epoch 16/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 43s 27ms/step - accuracy: 0.8445 - loss: 0.4517 - val_accuracy: 0.8358 - val_loss: 0.4947
# Epoch 17/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 43s 27ms/step - accuracy: 0.8495 - loss: 0.4366 - val_accuracy: 0.8349 - val_loss: 0.4938
# Epoch 18/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 44s 28ms/step - accuracy: 0.8544 - loss: 0.4148 - val_accuracy: 0.8448 - val_loss: 0.4635
# Epoch 19/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.8577 - loss: 0.4002 - val_accuracy: 0.8525 - val_loss: 0.4487
# Epoch 20/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.8656 - loss: 0.3870 - val_accuracy: 0.8457 - val_loss: 0.4804
# Epoch 21/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.8684 - loss: 0.3776 - val_accuracy: 0.8520 - val_loss: 0.4519
# Epoch 22/100
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.